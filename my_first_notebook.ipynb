# %%
Hardware
Physical parts of a computer (you can see and touch them)
Needed to run any system

Ex: Keyboard / Monitor / CPU

Software
Programs or instructions (you cannot touch, only use them)
Tells the hardware what to do
Runs on hardware

 Ex: Windows OS / Google Chrome / MS Word
